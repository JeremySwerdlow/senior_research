# %% [markdown]
# # Post-train Data Addition to Decision Trees in Python
# This .ipynb is a runnable environment for the final testing and demonstration of the work done for this research. In the same folder you can find four .py files which support this notebook. However, for the most simple examples, one can just run all of these cells in order, and see both trees and metrics for the research.
#
# The associated paper and poster with this research can also be found in the repository, as well as copies of the datasets used, and photos of the graphs generated for use in both the paper and poster.
#
# For any further questions, or comments, please contact Jeremy Swerdlow at [jjswerd14@earlham.edu](mailto:jjswerd14@earlham.edu)
#
# ## Imports

# %%
import data_prep as dp
import testing as tst

# %% [markdown]
# ## Graphing of Trees
# Graphs are automatically printed inline when run. Please use the .render() function to create .png images of the trees in the directory
#
# To create these graphs, the Graphviz dependencies are required. Please visit https://graphviz.readthedocs.io/en/stable/ for the installation of the python packages, and https://www.graphviz.org/download/ for the technology itself.

# %%
pet_df, pet_tree, pet_graph = dp.pets()
fv_day_df, fv_day_tree, fv_day_graph = dp.fv_day()
fv_day_2_df, fv_day_2_tree, fv_day_2_graph = dp.fv_day_2nd()
mushroom_df, mushroom_tree, mushroom_graph = dp.mushroom()

# %%
pet_graph

# %%
fv_day_graph

# %%
fv_day_2_graph

# %%
mushroom_graph

# %% [markdown]
# ## Testing for Metrics
# ### Random Split Testing

# %%
random_time_dict, random_test_res = tst.random_split_run()

# %%
tst.df_from_results(random_test_res, random_time_dict, 'pets')
# Out:
#          accuracy  recall  precision  f-score      time
# initial  0.333333     0.0        0.0      0.0  0.115491
# remade   0.000000     0.0        0.0      0.0  0.096974
# updated  0.333333     0.0        0.0      0.0  0.141323

# %%
tst.df_from_results(random_test_res, random_time_dict, 'five_day')
# Out:
#          accuracy  recall  precision  f-score      time
# initial  0.698795     0.0        0.0      0.0  0.304126
# remade   0.698795     0.0        0.0      0.0  0.290424
# updated  0.698795     0.0        0.0      0.0  1.415395

# %%
tst.df_from_results(random_test_res, random_time_dict, 'five_day_2')
# Out:
#          accuracy    recall  precision   f-score      time
# initial  0.747368  0.764493   0.967890  0.854251  1.556580
# remade   0.747368  0.764493   0.967890  0.854251  1.785827
# updated  0.740351  0.762774   0.958716  0.849593  4.104815

# %%
tst.df_from_results(random_test_res, random_time_dict, 'mushroom')
# Out:
#          accuracy  recall  precision  f-score       time
# initial       1.0     1.0        1.0      1.0   1.279615
# remade        1.0     1.0        1.0      1.0   1.176098
# updated       1.0     1.0        1.0      1.0  17.855069

# %% [markdown]
# ### New Node Added Testing

# %%
new_node_dict, new_node_test_res = tst.new_node_run()

# %%
tst.df_from_results(new_node_test_res, new_node_dict, 'pets')
# Out:
#          accuracy  recall  precision  f-score      time
# initial  0.333333     1.0   0.333333      0.5  0.054565
# remade   0.333333     1.0   0.333333      0.5  0.078554
# updated  0.333333     1.0   0.333333      0.5  0.039562

# %%
tst.df_from_results(new_node_test_res, new_node_dict, 'five_day')
# Out:
#          accuracy  recall  precision  f-score      time
# initial  0.751553     0.0        0.0      0.0  0.211637
# remade   0.751553     0.0        0.0      0.0  0.260464
# updated  0.751553     0.0        0.0      0.0  1.070879

# %%
tst.df_from_results(new_node_test_res, new_node_dict, 'five_day_2')
# Out:
#          accuracy    recall  precision   f-score      time
# initial  0.690647  0.707407   0.964646  0.816239  1.561236
# remade   0.701439  0.710623   0.979798  0.823779  1.988708
# updated  0.701439  0.710623   0.979798  0.823779  5.365761

# %%
tst.df_from_results(new_node_test_res, new_node_dict, 'mushroom')
# Out:
#          accuracy    recall  precision  f-score       time
# initial  0.998094  0.995868        1.0  0.99793   1.283095
# remade   1.000000  1.000000        1.0  1.00000   1.143861
# updated  1.000000  1.000000        1.0  1.00000  13.452872

# %% [markdown]
# ### Updated Weights Testing

# %%
update_time_dict, update_test_res = tst.new_data_run()

# %%
tst.df_from_results(update_test_res, update_time_dict, 'pets')
# Out:
#          accuracy    recall  precision  f-score      time
# initial  0.333333  0.333333        1.0      0.5  0.103950
# remade   0.333333  0.333333        1.0      0.5  0.098873
# updated  0.333333  0.333333        1.0      0.5  0.059968

# %%
tst.df_from_results(update_test_res, update_time_dict, 'five_day')
# Out:
#          accuracy    recall  precision   f-score      time
# initial  0.732919  0.745223   0.975000  0.844765  0.262060
# remade   0.689441  0.733333   0.916667  0.814815  0.238624
# updated  0.689441  0.733333   0.916667  0.814815  1.201642

# %%
tst.df_from_results(update_test_res, update_time_dict, 'five_day_2')
# Out:
#          accuracy    recall  precision   f-score      time
# initial  0.798561  0.800725   0.995495  0.887550  1.623065
# remade   0.798561  0.800725   0.995495  0.887550  1.687860
# updated  0.791367  0.799270   0.986486  0.883065  4.152574

# %%
tst.df_from_results(update_test_res, update_time_dict, 'mushroom')
# Out:
#          accuracy  recall  precision  f-score       time
# initial       1.0     1.0        1.0      1.0   1.039368
# remade        1.0     1.0        1.0      1.0   1.230007
# updated       1.0     1.0        1.0      1.0  12.603490
